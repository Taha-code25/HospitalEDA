# %% [markdown]
# # 📘 Pandas Series and DataFrames Lecture
#
# ## 🌟 Objective
# Understand and practice how to use Pandas Series and DataFrames for data analysis in Python.

# %%
# Importing the pandas library
import pandas as pd

# %% [markdown]
# ## ✅ Part 1: Pandas Series
#
# ### 🔍 What is a Series?
# A Series is a one-dimensional array-like object that holds data along with an associated index.

# %%
# Example 1: Basic Series
s = pd.Series([10, 20, 30, 40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Example 2: Custom Index
s = pd.Series([100, 200, 300], index=['a', 'b' , "c"])
print(s)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
# Accessing Series Elements
print(s['a'])  # By label
print(s[1])    # By position
# Out:
# 100
# 200
# /tmp/ipython-input-9-2559899508.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[1])    # By position

# %%
# Series from Dictionary
data = {'Math': 90, 'Science': 85, 'English': 88}
s = pd.Series(data)
s
# Out:
# Math       90
# Science    85
# English    88
# dtype: int64

# %% [markdown]
# ### 🎯 Task 1:
# Create a Series of 5 fruit names with prices.

# %%
# Task 1 Solution
fruit_prices = pd.Series([120, 80, 100, 150, 90],index=['Apple', 'Banana', 'Mango', 'Grapes', 'Orange'])
print(fruit_prices)
# Out:
# Apple     120
# Banana     80
# Mango     100
# Grapes    150
# Orange     90
# dtype: int64

# %% [markdown]
# ## 📈 Part 2: Pandas DataFrames
#
# ### 📊 What is a DataFrame?
# A DataFrame is a 2D labeled data structure with columns of potentially different types.

# %%
# Example 1: Create from Dictionary
data = {
    'Name': ['Ali', 'Sara', 'Ahmed'],
    'Age': [22, 25, 23],
    'Marks': [88, 92, 85]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age  Marks
# 0    Ali   22     88
# 1   Sara   25     92
# 2  Ahmed   23     85

# %%
# Example 2: Create from List of Dictionaries
data = [
    {'Name': 'Zara', 'Age': 21, 'Marks': 90},
    {'Name': 'Hassan', 'Age': 24, 'Marks': 80}
]
df = pd.DataFrame(data)
df
# Out:
#      Name  Age  Marks
# 0    Zara   21     90
# 1  Hassan   24     80

# %%
# Accessing Columns and Rows
print(df['Name'])
print(df[['Name', 'Marks']])
print(df.loc[0])  # by label
print(df.iloc[1]) # by position
# Out:
# 0      Zara
# 1    Hassan
# Name: Name, dtype: object
#      Name  Marks
# 0    Zara     90
# 1  Hassan     80
# Name     Zara
# Age        21
# Marks      90
# Name: 0, dtype: object
# Name     Hassan
# Age          24
# Marks        80
# Name: 1, dtype: object

# %%
df['Name']
# Out:
# 0      Zara
# 1    Hassan
# Name: Name, dtype: object

# %%
df[['Name', 'Marks']]
# Out:
#      Name  Marks
# 0    Zara     90
# 1  Hassan     80

# %%
df.loc[0]
# Out:
# Name     Zara
# Age        21
# Marks      90
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name     Hassan
# Age          24
# Marks        80
# Name: 1, dtype: object

# %%
data = [
    {'Name': 'Zara', 'Age': 21, 'Marks': 90},
    {'Name': 'Hassan', 'Age': 24, 'Marks': 80}
]
df = pd.DataFrame(data)
df.iloc[1]
# Out:
# Name     Hassan
# Age          24
# Marks        80
# Name: 1, dtype: object

# %%
# Adding a New Column
df['Grade'] = ['A', 'A+']
df
# Out:
#      Name  Age  Marks Grade
# 0    Zara   21     90     A
# 1  Hassan   24     80    A+

# %% [markdown]
# ### 🎯 Task 2:
# Create a DataFrame for 3 students with Name, Subject, and Score.

# %%
# Task 2 Solution
student_data = {
    'Name': ['Ayan', 'Zoya', 'Hamza'],
    'Subject': ['Math', 'English', 'Science'],
    'Score': [78, 82, 91]
}
df = pd.DataFrame(student_data)
print(df)
# Out:
#     Name  Subject  Score
# 0   Ayan     Math     78
# 1   Zoya  English     82
# 2  Hamza  Science     91

# %%
# Filtering Rows
df[df['Score'] > 80]
# Out:
#     Name  Subject  Score
# 1   Zoya  English     82
# 2  Hamza  Science     91

# %%
# Descriptive Statistics
df.describe()
# Out:
#            Score
# count   3.000000
# mean   83.666667
# std     6.658328
# min    78.000000
# 25%    80.000000
# 50%    82.000000
# 75%    86.500000
# max    91.000000

# %%
# Rename Column
df.rename(columns={'Score': 'Marks'}, inplace=True)

# %%
# Drop a Column
df.drop('Subject', axis=1, inplace=True)
df
# Out:
#     Name  Marks
# 0   Ayan     78
# 1   Zoya     82
# 2  Hamza     91

# %%
df
# Out:
#     Name  Marks
# 0   Ayan     78
# 1   Zoya     82
# 2  Hamza     91

# %%
# Sort by Column
df.sort_values(by='Marks', ascending=False)
# Out:
#     Name  Marks
# 2  Hamza     91
# 1   Zoya     82
# 0   Ayan     78

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Marks   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df.isnull().sum()
# Out:
# Name     0
# Marks    0
# dtype: int64

# %%
df.fillna(0)
# Out:
#     Name  Marks
# 0   Ayan     78
# 1   Zoya     82
# 2  Hamza     91

# %%
df.dropna()
# Out:
#     Name  Marks
# 0   Ayan     78
# 1   Zoya     82
# 2  Hamza     91

# %%
df.sort_values(by='Marks')
# Out:
#     Name  Marks
# 0   Ayan     78
# 1   Zoya     82
# 2  Hamza     91

# %% [markdown]
# ### 🎯 Task 3:
# Add a column `Passed` with value `True` if Marks > 80.

# %%
# Task 3 Solution
df['Passed'] = df['Marks'] > 80
print(df)

# %% [markdown]
# ## ⭐ Handy DataFrame Functions with Examples

# %%
print(df.head())
print(df.tail())
print(df.shape)
print(df.columns)
df.info()
print(df.isnull())
print(df.fillna(0))
print(df.dropna())
print(df.sort_values(by='Marks'))

# %% [markdown]
# ## 📚 Final Assignments
# 1. Create a Pandas Series of 6 countries and their populations.
# 2. Create a DataFrame for 5 employees with Name, Department, Salary, and Experience.
# 3. Add a column `Bonus` = 15% of salary.
# 4. Filter employees with more than 3 years of experience.
# 5. Sort employees based on Salary in descending order.
